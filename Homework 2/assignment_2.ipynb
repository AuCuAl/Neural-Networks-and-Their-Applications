# %% [markdown]
# # <center>第二次作业</center>
# ## <center>金桐宇 BZ25219005</center>

# %% [markdown]
# ### 1. 实验环境

# %% [markdown]
# 实验核心软硬件环境为显卡iGame GeForce RTX4060 Ultra W DUO OC，CUDA release 12.6, V12.6.85，python 3.11.15，pytorch及torchvision 2.10.0+cu126
#
# 实验设备规格图如下：
# ![sysinfo.png](../environments/sysinfo.png)
#
# 如下图所示，训练不同模型时GPU占用情况不同，训练RESNET-18时GPU占用较高，甚至会出现70%以上的占用，而别的网络可能只有30%的占用。
# ![taskmgr.png](../environments/taskmgr.png)
#
# CUDA 环境如下：
#
# ```
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Wed_Oct_30_01:18:48_Pacific_Daylight_Time_2024
# Cuda compilation tools, release 12.6, V12.6.85
# Build cuda_12.6.r12.6/compiler.35059454_0
# ```
#
# conda 环境如下：
#
# ```
# name: neural_networks_and_their_applications
# channels:
#   - https://mirrors.ustc.edu.cn/anaconda/pkgs/free
#   - https://mirrors.ustc.edu.cn/anaconda/pkgs/free/
#   - defaults
# dependencies:
#   - anyio=4.12.1=py311haa95532_0
#   - argon2-cffi=25.1.0=py311haa95532_0
#   - argon2-cffi-bindings=25.1.0=py311h02ab6af_0
#   - asttokens=3.0.1=py311haa95532_0
#   - async-lru=2.0.5=py311haa95532_0
#   - attrs=26.1.0=py311h35db113_0
#   - babel=2.17.0=py311haa95532_0
#   - beautifulsoup4=4.14.3=py311haa95532_0
#   - blas=1.0=mkl
#   - bleach=6.3.0=py311haa95532_0
#   - brotlicffi=1.2.0.0=py311h885b0b7_0
#   - bzip2=1.0.8=h2bbff1b_6
#   - ca-certificates=2025.12.2=haa95532_0
#   - cairo=1.18.4=he9e932c_0
#   - certifi=2026.01.04=py311haa95532_0
#   - cffi=2.0.0=py311h02ab6af_1
#   - charset-normalizer=3.4.4=py311haa95532_0
#   - colorama=0.4.6=py311haa95532_0
#   - comm=0.2.3=py311haa95532_0
#   - contourpy=1.3.3=py311h214f63a_0
#   - cycler=0.12.1=py311haa95532_0
#   - debugpy=1.8.16=py311h885b0b7_1
#   - decorator=5.2.1=py311haa95532_0
#   - defusedxml=0.7.1=pyhd3eb1b0_0
#   - executing=2.2.1=py311haa95532_0
#   - expat=2.7.5=hd7fb8db_0
#   - fontconfig=2.15.0=hd211d86_0
#   - fonttools=4.62.1=py311h1c6eee0_0
#   - freetype=2.14.1=hfbffc0b_0
#   - graphite2=1.3.14=hd77b12b_1
#   - h11=0.16.0=py311haa95532_1
#   - harfbuzz=10.2.0=he2f9f60_1
#   - html5lib=1.1=pyhd3eb1b0_0
#   - httpcore=1.0.9=py311haa95532_0
#   - httpx=0.28.1=py311haa95532_1
#   - icu=73.1=h6c2663c_0
#   - idna=3.11=py311haa95532_0
#   - intel-openmp=2025.0.0=haa95532_1164
#   - ipykernel=7.2.0=py311h4442805_0
#   - ipython=9.10.0=py311haa95532_0
#   - ipython_pygments_lexers=1.1.1=py311haa95532_0
#   - ipywidgets=8.1.7=py311haa95532_1
#   - jedi=0.19.2=py311haa95532_0
#   - jinja2=3.1.6=py311haa95532_0
#   - jpeg=9f=ha349fce_0
#   - json5=0.12.1=py311haa95532_0
#   - jsonschema=4.25.1=py311haa95532_0
#   - jsonschema-specifications=2025.9.1=py311haa95532_0
#   - jupyter=1.1.1=py311haa95532_0
#   - jupyter-lsp=2.3.0=py311haa95532_0
#   - jupyter_client=8.8.0=py311haa95532_0
#   - jupyter_console=6.6.3=py311haa95532_0
#   - jupyter_core=5.9.1=py311haa95532_0
#   - jupyter_events=0.12.0=py311haa95532_1
#   - jupyter_server=2.17.0=py311haa95532_1
#   - jupyter_server_terminals=0.5.4=py311haa95532_0
#   - jupyterlab=4.5.3=py311haa95532_1
#   - jupyterlab_pygments=0.3.0=py311haa95532_0
#   - jupyterlab_server=2.28.0=py311haa95532_1
#   - jupyterlab_widgets=3.0.16=py311haa95532_1
#   - kiwisolver=1.4.9=py311h03f52e7_0
#   - lcms2=2.16=hb4a4139_0
#   - lerc=3.0=hd77b12b_0
#   - libdeflate=1.17=h2bbff1b_1
#   - libexpat=2.7.5=hd7fb8db_0
#   - libffi=3.4.4=hd77b12b_1
#   - libglib=2.86.3=h9bccc14_0
#   - libhwloc=2.12.1=default_hfa10c62_1000
#   - libiconv=1.18=hc89ec93_0
#   - libkrb5=1.22.1=hb237eb7_0
#   - libpng=1.6.56=h2854ad3_0
#   - libpq=17.6=h64815fc_1
#   - libsodium=1.0.20=h83e8143_0
#   - libtiff=4.5.1=hd77b12b_0
#   - libwebp-base=1.6.0=hbf3958f_0
#   - libxml2=2.13.9=h6201b9f_0
#   - libzlib=1.3.1=h02ab6af_0
#   - lz4-c=1.9.4=h2bbff1b_1
#   - matplotlib=3.10.8=py311haa95532_0
#   - matplotlib-base=3.10.8=py311h26e45b9_0
#   - matplotlib-inline=0.2.1=py311haa95532_0
#   - mistune=3.1.2=py311haa95532_0
#   - mkl=2025.0.0=h5da7b33_930
#   - mkl-service=2.5.2=py311h0b37514_0
#   - mkl_fft=2.1.1=py311h300f80d_0
#   - mkl_random=1.3.0=py311ha5e6156_0
#   - mysql-common=9.3.0=h0b12ad4_5
#   - mysql-libs=9.3.0=hcb0c519_5
#   - nbclient=0.10.4=py311haa95532_0
#   - nbconvert=7.17.0=py311haa95532_0
#   - nbconvert-core=7.17.0=py311haa95532_0
#   - nbconvert-pandoc=7.17.0=py311haa95532_0
#   - nbformat=5.10.4=py311haa95532_0
#   - nest-asyncio=1.6.0=py311haa95532_0
#   - notebook=7.5.3=py311haa95532_0
#   - notebook-shim=0.2.4=py311haa95532_1
#   - numpy=2.4.3=py311h22cce72_0
#   - numpy-base=2.4.3=py311h1df51cf_0
#   - openjpeg=2.5.2=hae555c5_0
#   - openssl=3.5.5=hbb43b14_0
#   - overrides=7.7.0=py311haa95532_0
#   - packaging=25.0=py311haa95532_1
#   - pandas=3.0.1=py311hf6ff4c0_0
#   - pandoc=3.8=haa95532_0
#   - pandocfilters=1.5.1=py311haa95532_0
#   - parso=0.8.5=py311haa95532_0
#   - pcre2=10.46=h5740b90_0
#   - pillow=11.1.0=py311h096bfcc_0
#   - pip=26.0.1=pyhc872135_0
#   - pixman=0.46.4=h4043f72_0
#   - platformdirs=4.9.4=py311haa95532_0
#   - prometheus_client=0.24.1=py311haa95532_0
#   - prompt-toolkit=3.0.52=py311haa95532_1
#   - prompt_toolkit=3.0.52=hd3eb1b0_1
#   - psutil=7.0.0=py311h02ab6af_1
#   - pure_eval=0.2.3=py311haa95532_0
#   - pycparser=3.0=py311haa95532_0
#   - pygments=2.19.2=py311haa95532_0
#   - pyparsing=3.2.5=py311haa95532_0
#   - pyqt=6.9.1=py311h12ec796_0
#   - pyqt6-sip=13.10.2=py311h630b2a1_0
#   - pysocks=1.7.1=py311haa95532_1
#   - python=3.11.15=h1044e36_0
#   - python-dateutil=2.9.0post0=py311haa95532_2
#   - python-fastjsonschema=2.21.2=py311haa95532_0
#   - python-json-logger=4.0.0=py311haa95532_0
#   - python-tzdata=2025.3=pyhd3eb1b0_0
#   - pywin32=311=py311h885b0b7_0
#   - pywinpty=2.0.15=py311hd93a960_1
#   - pyyaml=6.0.3=py311hb9a58be_0
#   - pyzmq=27.1.0=py311h7149c55_1
#   - qtbase=6.9.2=hd965823_2
#   - qtconsole=5.7.1=py311haa95532_0
#   - qtdeclarative=6.9.2=h88b4c33_1
#   - qtpy=2.4.3=py311haa95532_0
#   - qtsvg=6.9.2=h30ace32_1
#   - qttools=6.9.2=h7e7b719_1
#   - qtwebchannel=6.9.2=heb02b0b_1
#   - qtwebsockets=6.9.2=heb02b0b_1
#   - referencing=0.37.0=py311haa95532_0
#   - requests=2.32.5=py311haa95532_1
#   - rfc3339-validator=0.1.4=py311haa95532_0
#   - rfc3986-validator=0.1.1=py311haa95532_0
#   - rpds-py=0.28.0=py311h114bc41_0
#   - seaborn=0.13.2=py311haa95532_3
#   - send2trash=1.8.3=py311haa95532_0
#   - setuptools=80.10.2=py311haa95532_0
#   - sip=6.12.0=py311h706e071_0
#   - six=1.17.0=py311haa95532_0
#   - soupsieve=2.5=py311haa95532_0
#   - sqlite=3.51.2=hee5a0db_0
#   - stack_data=0.6.3=py311haa95532_0
#   - tbb=2022.3.0=h90c84d6_0
#   - tbb-devel=2022.3.0=h90c84d6_0
#   - terminado=0.18.1=py311haa95532_1
#   - tinycss2=1.4.0=py311haa95532_0
#   - tk=8.6.15=hf199647_0
#   - tornado=6.5.5=py311h1c6eee0_0
#   - traitlets=5.14.3=py311haa95532_0
#   - typing-extensions=4.15.0=py311haa95532_0
#   - typing_extensions=4.15.0=py311haa95532_0
#   - tzdata=2026a=he532380_0
#   - ucrt=10.0.22621.0=haa95532_0
#   - urllib3=2.6.3=py311haa95532_0
#   - vc=14.3=h2df5915_10
#   - vc14_runtime=14.44.35208=h4927774_10
#   - vs2015_runtime=14.44.35208=ha6b5a95_10
#   - wcwidth=0.2.14=py311haa95532_0
#   - webencodings=0.5.1=py311haa95532_1
#   - websocket-client=1.8.0=py311haa95532_0
#   - wheel=0.46.3=py311haa95532_0
#   - widgetsnbextension=4.0.14=py311haa95532_0
#   - win_inet_pton=1.1.0=py311haa95532_1
#   - winpty=0.4.3=haa95532_5
#   - xz=5.8.2=h53af0af_0
#   - yaml=0.2.5=he774522_0
#   - zeromq=4.3.5=h6c54ac7_1
#   - zlib=1.3.1=h02ab6af_0
#   - zstd=1.5.7=h56299aa_0
#   - pip:
#       - filelock==3.25.2
#       - fsspec==2026.2.0
#       - joblib==1.5.3
#       - markupsafe==3.0.3
#       - mpmath==1.3.0
#       - networkx==3.6.1
#       - scikit-learn==1.8.0
#       - scipy==1.17.1
#       - sympy==1.14.0
#       - threadpoolctl==3.6.0
#       - torch==2.10.0+cu126
#       - torchaudio==2.10.0+cu126
#       - torchvision==0.25.0+cu126
# prefix: E:\ProgramData\anaconda3\envs\neural_networks_and_their_applications
# ```
#
# pip 环境如下：
#
# ```
# anyio @ file:///C:/Users/task_177313442920801/croot/anyio_1773134524138/work
# argon2-cffi @ file:///C:/Users/task_176606713276293/croot/argon2-cffi_1766067885361/work
# argon2-cffi-bindings @ file:///C:/miniconda3/conda-bld/argon2-cffi-bindings_1757925007150/work
# asttokens @ file:///C:/Users/task_177313470048861/croot/asttokens_1773135664256/work
# async-lru @ file:///C:/miniconda3/conda-bld/async-lru_1761121591843/work
# attrs @ file:///C:/Users/task_177495968274377/croot/attrs_1774959754711/work
# babel @ file:///C:/miniconda3/conda-bld/babel_1764159347172/work
# beautifulsoup4 @ file:///C:/Users/task_177029184171008/croot/beautifulsoup4-split_1770291942989/work
# bleach @ file:///C:/miniconda3/conda-bld/bleach_1764153681122/work
# brotlicffi @ file:///C:/miniconda3/conda-bld/brotlicffi_1764961370587/work
# certifi @ file:///C:/Users/task_176765900829408/croot/certifi_1767659214946/work/certifi
# cffi @ file:///C:/miniconda3/conda-bld/cffi_1761832792265/work
# charset-normalizer @ file:///C:/miniconda3/conda-bld/charset-normalizer_1761745005832/work
# colorama @ file:///C:/ci_311/colorama_1676422310965/work
# comm @ file:///C:/miniconda3/conda-bld/comm_1763119240032/work
# contourpy @ file:///C:/miniconda3/conda-bld/contourpy_1763643940930/work
# cycler @ file:///C:/Users/task_176606795187315/croot/cycler_1766068055927/work
# debugpy @ file:///C:/miniconda3/conda-bld/debugpy_1762421657701/work
# decorator @ file:///C:/miniconda3/conda-bld/decorator_1757341249812/work
# defusedxml @ file:///tmp/build/80754af9/defusedxml_1615228127516/work
# executing @ file:///C:/miniconda3/conda-bld/executing_1757061250618/work
# fastjsonschema @ file:///C:/miniconda3/conda-bld/python-fastjsonschema_1763718732564/work
# filelock==3.25.2
# fonttools @ file:///C:/Users/task_177425651858234/croot/fonttools_1774256593156/work
# fsspec==2026.2.0
# h11 @ file:///C:/miniconda3/conda-bld/h11_1761931279881/work
# html5lib @ file:///Users/ktietz/demo/mc3/conda-bld/html5lib_1629144453894/work
# httpcore @ file:///C:/b/abs_25m7_xthp6/croot/httpcore_1748526065845/work
# httpx @ file:///C:/miniconda3/conda-bld/httpx_1760447374704/work
# idna @ file:///C:/miniconda3/conda-bld/idna_1761912044050/work
# ipykernel @ file:///C:/Users/task_177261243624985/croot/ipykernel_1772612530162/work
# ipython @ file:///C:/Users/task_177331748463056/croot/ipython_1773317859290/work
# ipython_pygments_lexers @ file:///C:/b/abs_b66hj1lo19/croot/ipython_pygments_lexers_1744753262043/work
# ipywidgets @ file:///C:/Users/task_177149936715045/croot/ipywidgets_1771500058372/work
# jedi @ file:///C:/b/abs_3a2kbnlclc/croot/jedi_1733987412687/work
# Jinja2 @ file:///C:/b/abs_920kup4e6u/croot/jinja2_1741711580669/work
# joblib==1.5.3
# json5 @ file:///C:/miniconda3/conda-bld/json5_1763718659894/work
# jsonschema @ file:///C:/Users/task_176795546861110/croot/jsonschema_1767955573227/work
# jsonschema-specifications @ file:///C:/miniconda3/conda-bld/jsonschema-specifications_1762788559143/work
# jupyter @ file:///C:/b/abs_32aohix0i1/croot/jupyter_1737645821205/work
# jupyter-console @ file:///C:/b/abs_82xaa6i2y4/croot/jupyter_console_1680000189372/work
# jupyter-events @ file:///C:/miniconda3/conda-bld/jupyter_events_1765813625854/work
# jupyter-lsp @ file:///C:/Users/task_176977264821400/croot/jupyter-lsp_1769772760423/work
# jupyter_client @ file:///C:/Users/task_176839910354009/croot/jupyter_client_1768399225952/work
# jupyter_core @ file:///C:/miniconda3/conda-bld/jupyter_core_1764588344213/work
# jupyter_server @ file:///C:/Users/task_176961318855095/croot/jupyter_server_1769613456739/work
# jupyter_server_terminals @ file:///C:/Users/task_177028947499322/croot/jupyter_server_terminals_1770289599454/work
# jupyterlab @ file:///C:/Users/task_177021308886759/croot/jupyterlab_1770213194854/work
# jupyterlab_pygments @ file:///C:/b/abs_d5alfet8m6/croot/jupyterlab_pygments_1741124274578/work
# jupyterlab_server @ file:///C:/Users/task_176962938560339/croot/jupyterlab_server_1769629890799/work
# jupyterlab_widgets @ file:///C:/Users/task_177149229574922/croot/jupyterlab_widgets_1771492419777/work
# kiwisolver @ file:///C:/miniconda3/conda-bld/kiwisolver_1764159382796/work
# MarkupSafe @ file:///C:/b/abs_a0ma7ge0jc/croot/markupsafe_1738584052792/work
# matplotlib==3.10.8
# matplotlib-inline @ file:///C:/miniconda3/conda-bld/matplotlib-inline_1762779272071/work
# mistune @ file:///C:/b/abs_77yql3poyz/croot/mistune_1741124004410/work
# mkl-service==2.5.2
# mkl_fft @ file:///C:/miniconda3/conda-bld/mkl_fft_1761592920106/work
# mkl_random @ file:///C:/miniconda3/conda-bld/mkl_random_1761593150425/work
# mpmath==1.3.0
# nbclient @ file:///C:/Users/task_177157717178214/croot/nbclient_1771577291620/work
# nbconvert @ file:///C:/Users/task_177212083391277/croot/nbconvert-meta_1772121327226/work
# nbformat @ file:///C:/b/abs_c2jkw46etm/croot/nbformat_1728050303821/work
# nest-asyncio @ file:///C:/b/abs_65d6lblmoi/croot/nest-asyncio_1708532721305/work
# networkx==3.6.1
# notebook @ file:///C:/Users/task_177028951092727/croot/notebook_1770289613770/work
# notebook_shim @ file:///C:/Users/task_176962931554331/croot/notebook-shim_1769629908292/work
# numpy @ file:///C:/Users/task_177399617241716/croot/numpy_and_numpy_base_1773996243769/work/dist/numpy-2.4.3-cp311-cp311-win_amd64.whl#sha256=1e445656686729ce1477b9f9214768a9cdac73a13f681278870b76517fe9c009
# overrides @ file:///C:/miniconda3/conda-bld/overrides_1762349150310/work
# packaging @ file:///C:/miniconda3/conda-bld/packaging_1761049096285/work
# pandas @ file:///C:/Users/task_177324594340079/croot/pandas_1773246094874/work
# pandocfilters @ file:///C:/miniconda3/conda-bld/pandocfilters_1756977624481/work
# parso @ file:///C:/miniconda3/conda-bld/parso_1762781926029/work
# pillow @ file:///C:/b/abs_b50vowcrzo/croot/pillow_1738010273782/work
# platformdirs @ file:///C:/Users/task_177365235863468/croot/platformdirs_1773652992932/work
# prometheus_client @ file:///C:/Users/task_177273339182086/croot/prometheus_client_1772733455299/work
# prompt_toolkit @ file:///C:/miniconda3/conda-bld/prompt-toolkit_1761745034319/work
# psutil @ file:///C:/miniconda3/conda-bld/psutil_1761896536656/work
# pure_eval @ file:///C:/miniconda3/conda-bld/pure_eval_1757067065603/work
# pycparser @ file:///C:/Users/task_177495971060608/croot/pycparser_1774959807716/work
# Pygments @ file:///C:/miniconda3/conda-bld/pygments_1762431425708/work
# pyparsing @ file:///C:/miniconda3/conda-bld/pyparsing_1763973807786/work
# PyQt6==6.9.1
# PyQt6_sip @ file:///C:/miniconda3/conda-bld/pyqt-split_1757511038427/work/pyqt_sip
# PySocks @ file:///C:/miniconda3/conda-bld/pysocks_1761753028158/work
# python-dateutil @ file:///C:/b/abs_3au_koqnbs/croot/python-dateutil_1716495777160/work
# python-json-logger @ file:///C:/miniconda3/conda-bld/python-json-logger_1764590274458/work
# pywin32 @ file:///C:/b/abs_6c9w_vp9zi/croot/pywin32_1754670534373/work
# pywinpty @ file:///C:/Users/task_176958928208665/croot/pywinpty_1769589538944/work
# PyYAML @ file:///C:/miniconda3/conda-bld/pyyaml_1763465512847/work
# pyzmq @ file:///C:/miniconda3/conda-bld/pyzmq_1762375608224/work
# qtconsole @ file:///C:/Users/task_177149720441271/croot/qtconsole_1771497540644/work
# QtPy @ file:///C:/miniconda3/conda-bld/qtpy_1757531228141/work
# referencing @ file:///C:/miniconda3/conda-bld/referencing_1762536905217/work
# requests @ file:///C:/miniconda3/conda-bld/requests_1762359611410/work
# rfc3339-validator @ file:///C:/b/abs_ddfmseb_vm/croot/rfc3339-validator_1683077054906/work
# rfc3986-validator @ file:///C:/b/abs_6e9azihr8o/croot/rfc3986-validator_1683059049737/work
# rpds-py @ file:///C:/miniconda3/conda-bld/rpds-py_1762366642821/work
# scikit-learn==1.8.0
# scipy==1.17.1
# seaborn @ file:///C:/b/abs_0bv5x0ucxb/croot/seaborn_1749110315600/work
# Send2Trash @ file:///C:/Users/task_176817069519266/croot/send2trash_1768170816011/work
# sip @ file:///C:/b/abs_f6ow8vlbb7/croot/sip_1756224172742/work
# six @ file:///C:/b/abs_149wuyuo1o/croot/six_1744271521515/work
# soupsieve @ file:///C:/b/abs_bbsvy9t4pl/croot/soupsieve_1696347611357/work
# stack_data @ file:///C:/miniconda3/conda-bld/stack_data_1757067061065/work
# sympy==1.14.0
# terminado @ file:///C:/Users/task_176959141466282/croot/terminado_1769591760225/work
# threadpoolctl==3.6.0
# tinycss2 @ file:///C:/b/abs_df38owi5ma/croot/tinycss2_1738337725183/work
# torch==2.10.0+cu126
# torchaudio==2.10.0+cu126
# torchvision==0.25.0+cu126
# tornado @ file:///C:/Users/task_177430354887534/croot/tornado_1774303656328/work
# traitlets @ file:///C:/b/abs_bfsnoxl4pq/croot/traitlets_1718227069245/work
# typing_extensions @ file:///C:/b/abs_ecq8gc0vbm/croot/typing_extensions_1756281142218/work
# tzdata @ file:///home/task_176829656558347/croot/python-tzdata_1768296637279/work
# urllib3 @ file:///C:/Users/task_176781036847582/croot/urllib3_1767810492638/work
# wcwidth @ file:///C:/Users/task_176777899121830/croot/wcwidth_1767779217471/work
# webencodings==0.5.1
# websocket-client @ file:///C:/b/abs_5dmnxxoci9/croot/websocket-client_1715878351319/work
# widgetsnbextension @ file:///C:/miniconda3/conda-bld/widgetsnbextension_1761556763484/work
# win_inet_pton @ file:///C:/miniconda3/conda-bld/win_inet_pton_1761746278197/work
# ```

# %% [markdown]
# ### 2. 模型定义

# %% [markdown]
# model.py
#
# 该文件定义了LeNet5，基础 CNN，缩小版 AlexNet，ResNet-18，MobileNetV2五种网络。
#
# 开头的 import pandas as pd 没有任何意义，但不导入会导致导入torch时发生OMP: Error #15错误，在jupyter中则会直接卡死，十分玄学。

# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models

# 1. 经典 LeNet-5 (适配 32x32)
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.model_name = "LeNet5"
        self.conv1 = nn.Conv2d(3, 6, kernel_size=5)
        self.conv2 = nn.Conv2d(6, 16, kernel_size=5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = F.max_pool2d(F.relu(self.conv1(x)), 2)
        x = F.max_pool2d(F.relu(self.conv2(x)), 2)
        x = x.view(-1, 16 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# 2. 基础 CNN
class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.model_name = "SimpleCNN"
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 8 * 8, 512)
        self.fc2 = nn.Linear(512, 10)
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 64 * 8 * 8)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# 3. 缩小版 AlexNet (Mini-AlexNet)
class MiniAlexNet(nn.Module):
    def __init__(self):
        super(MiniAlexNet, self).__init__()
        self.model_name = "MiniAlexNet"
        self.features = nn.Sequential(
            nn.Conv2d(3, 48, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(48, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(128, 192, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(192, 192, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(192, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )
        self.classifier = nn.Sequential(
            nn.Dropout(),
            nn.Linear(128 * 4 * 4, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(512, 10),
        )

    def forward(self, x):
        x = self.features(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# 4. ResNet-18 (使用 torchvision 并修改分类头)
class ResNetModel(nn.Module):
    def __init__(self):
        super(ResNetModel, self).__init__()
        self.model_name = "ResNet18"
        self.model = models.resnet18(weights=None)
        # 修改第一层卷积以更好适应 32x32 (非必须，但推荐)
        self.model.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.model.maxpool = nn.Identity() # 取消原本的 maxpool 避免过度下采样
        self.model.fc = nn.Linear(self.model.fc.in_features, 10)

    def forward(self, x):
        return self.model(x)

# 5. MobileNetV2 (轻量级网络)
class MobileNetModel(nn.Module):
    def __init__(self):
        super(MobileNetModel, self).__init__()
        self.model_name = "MobileNetV2"
        self.model = models.mobilenet_v2(weights=None)
        # 修改分类头
        self.model.classifier[1] = nn.Linear(self.model.last_channel, 10)

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ### 3. 模型训练与评估

# %% [markdown]
# train_and_eval.py
#
# 该文件进行模型训练与评估，将训练集与数据集的损失及准确率写入./history文件夹中的json文件。
#
# 对于CNN，根据输入数据是否增强做了消融实验，增强数据包括训练集先填充4像素，再裁回32x32的随机裁剪以及随机微小旋转。测试集不进行数据增强。由于在数据预处理函数在定义的函数外部，因此这里并不是很方便处理。

# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import os
import json
import logging
from datetime import datetime

# 导入所有自定义模型
from models import LeNet5, SimpleCNN, MiniAlexNet, ResNetModel, MobileNetModel

# --- 全局变量初始化 ---
BATCH_SIZE = 128
EPOCHS = 20
LEARNING_RATE = 0.001
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
DATA_ROOT = './dataset' # 指定数据集目录
LOG_DIR = './log'
MODEL_DIR = './model'
HISTORY_DIR = './history'
AUGMENTED_MODEL_DIR = f'{MODEL_DIR}/augmented'
AUGMENTED_HISTORY_DIR = f'{HISTORY_DIR}/augmented'

# 确保必要目录存在
os.makedirs(DATA_ROOT, exist_ok=True)
os.makedirs(LOG_DIR, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(HISTORY_DIR, exist_ok=True)
os.makedirs(AUGMENTED_MODEL_DIR, exist_ok=True)
os.makedirs(AUGMENTED_HISTORY_DIR, exist_ok=True)
# os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE' # 解决 OpenMP 冲突，我在最前面导入pandas莫名奇妙解决了OMP: Error #15

# --- 配置 Logging 系统 ---
log_filename = f"{datetime.now().strftime('%Y%m%d_%H%M%S')}.log"
log_path = os.path.join(LOG_DIR, log_filename)

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(log_path, encoding='utf-8'),
        logging.StreamHandler() # 同时输出到控制台
    ]
)
logger = logging.getLogger(__name__)

# --- 数据预处理与加载 ---
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# --- 训练集数据增强 ---
train_transform_aug = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# 加载 SVHN Format 2 数据集 (确保 train_32x32.mat 在 dataset/ 目录下)
train_set = datasets.SVHN(root=DATA_ROOT, split='train', download=True, transform=transform)
train_set_aug = datasets.SVHN(root=DATA_ROOT, split='train', download=True, transform=train_transform_aug)
test_set = datasets.SVHN(root=DATA_ROOT, split='test', download=True, transform=transform)

train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True)
train_loader_aug = DataLoader(train_set_aug, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(test_set, batch_size=BATCH_SIZE, shuffle=False)

# --- 不增强 ---

def train_and_eval(model):
    model_name = model.model_name
    model = model.to(DEVICE)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

    history = {'train_loss': [], 'test_loss': [], 'train_acc': [], 'test_acc': []}

    for epoch in range(EPOCHS):
        # 训练阶段
        model.train()
        running_loss, correct, total = 0.0, 0, 0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

        train_loss = running_loss / len(train_loader)
        train_acc = 100. * correct / total

        # 测试阶段
        model.eval()
        test_loss, correct, total = 0.0, 0, 0
        with torch.no_grad():
            for inputs, labels in test_loader:
                inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                test_loss += loss.item()
                _, predicted = outputs.max(1)
                total += labels.size(0)
                correct += predicted.eq(labels).sum().item()

        test_loss /= len(test_loader)
        test_acc = 100. * correct / total

        # 记录数据
        history['train_loss'].append(train_loss)
        history['test_loss'].append(test_loss)
        history['train_acc'].append(train_acc)
        history['test_acc'].append(test_acc)

        logger.info(f"[{model_name}] Epoch {epoch+1}/{EPOCHS} - "
                    f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}% | "
                    f"Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.2f}%")

    with open(f'{HISTORY_DIR}/{model_name}.json', 'w') as f:
        json.dump(history, f)
    torch.save(model.state_dict(), f'{MODEL_DIR}/{model_name}.pth')
    logger.info("不增强模型与历史数据 JSON 已保存。")

# --- 增强 ---

def train_and_eval_augmentation(model):
    model_name = model.model_name
    model = model.to(DEVICE)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

    history = {'train_loss': [], 'test_loss': [], 'train_acc': [], 'test_acc': []}

    for epoch in range(EPOCHS):
        # 训练阶段
        model.train()
        running_loss, correct, total = 0.0, 0, 0
        for inputs, labels in train_loader_aug:
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

        train_loss = running_loss / len(train_loader_aug)
        train_acc = 100. * correct / total

        # 测试阶段
        model.eval()
        test_loss, correct, total = 0.0, 0, 0
        with torch.no_grad():
            for inputs, labels in test_loader:
                inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                test_loss += loss.item()
                _, predicted = outputs.max(1)
                total += labels.size(0)
                correct += predicted.eq(labels).sum().item()

        test_loss /= len(test_loader)
        test_acc = 100. * correct / total

        # 记录数据
        history['train_loss'].append(train_loss)
        history['test_loss'].append(test_loss)
        history['train_acc'].append(train_acc)
        history['test_acc'].append(test_acc)

        logger.info(f"[{model_name}] Epoch {epoch+1}/{EPOCHS} - "
                    f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}% | "
                    f"Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.2f}%")

    with open(f'{AUGMENTED_HISTORY_DIR}/{model_name}_augmented.json', 'w') as f:
        json.dump(history, f)
    torch.save(model.state_dict(), f'{AUGMENTED_MODEL_DIR}/{model_name}_.pth')
    logger.info("增强模型与历史数据 JSON 已保存。")

# %% [markdown]
# ### 4. 结果可视化

# %% [markdown]
# plot.py
#
# 该文件读取./history文件夹中的json文件，根据不同模型训练集及测试集的损失及准确率绘制图线。
#
# 同时对于CNN还根据输入是否增强进行了消融实验，根据损失及准确率绘制图线。

# %%
import matplotlib.pyplot as plt
import json
import os
import glob

# --- 目录配置 ---
HISTORY_DIR = './history' # 确保你在 train_and_eval.py 中生成的 json 都放在了这个目录下
FIGURES_DIR = './Figures'
AUGMENTED_HISTORY_DIR = f'{HISTORY_DIR}/augmented'

# 自动创建 Figures 目录（如果不存在）
os.makedirs(FIGURES_DIR, exist_ok=True)

def plot_all_models():
    # 自动获取 history 目录下所有的 json 文件
    json_files = glob.glob(os.path.join(HISTORY_DIR, '*.json'))

    if not json_files:
        print(f"⚠️ 在 {HISTORY_DIR} 目录下没有找到任何 .json 文件，请检查路径！")
        return

    # 创建画布 (稍微加宽一点，给图例和标注留出空间)
    plt.figure(figsize=(15, 6))

    # 获取 Matplotlib 预设的高对比度颜色列表 (tab10 包含10种极具区分度的颜色)
    colors = plt.cm.tab10.colors

    for idx, file_path in enumerate(json_files):
        # 从文件名中提取模型名称，自动兼容带有 "_history" 后缀的情况
        base_name = os.path.basename(file_path)
        model_name = base_name.replace('_history.json', '').replace('.json', '')

        # 为当前模型分配一种固定颜色
        color = colors[idx % len(colors)]

        # 读取数据
        with open(file_path, 'r', encoding='utf-8') as f:
            history = json.load(f)

        epochs = range(1, len(history['train_loss']) + 1)
        last_epoch = epochs[-1]

        # ==========================================
        # 1. 绘制损失曲线 (左侧)
        # ==========================================
        plt.subplot(1, 2, 1)
        # 实线: 训练集 | 虚线: 测试集
        plt.plot(epochs, history['train_loss'], linestyle='-', color=color, label=f'{model_name} (Train)')
        plt.plot(epochs, history['test_loss'], linestyle='--', color=color, label=f'{model_name} (Test)')

        # 标注最后一次 epoch 的 Test Loss
        last_test_loss = history['test_loss'][-1]
        plt.annotate(f"{last_test_loss:.3f}",
                     xy=(last_epoch, last_test_loss),
                     xytext=(5, 0), textcoords='offset points',
                     color=color, fontsize=9, va='center')

        # ==========================================
        # 2. 绘制准确率曲线 (右侧)
        # ==========================================
        plt.subplot(1, 2, 2)
        # 实线: 训练集 | 虚线: 测试集
        plt.plot(epochs, history['train_acc'], linestyle='-', color=color, label=f'{model_name} (Train)')
        plt.plot(epochs, history['test_acc'], linestyle='--', color=color, label=f'{model_name} (Test)')

        # 标注最后一次 epoch 的 Test Acc
        last_test_acc = history['test_acc'][-1]
        plt.annotate(f"{last_test_acc:.1f}%",
                     xy=(last_epoch, last_test_acc),
                     xytext=(5, 0), textcoords='offset points',
                     color=color, fontsize=9, va='center')

        # (智能优化) 找出测试集准确率的最高点并用星号标注
        max_test_acc = max(history['test_acc'])
        max_acc_epoch = epochs[history['test_acc'].index(max_test_acc)]

        # 如果最高点不是最后一个点，我们才额外标注它，防止重叠
        if max_acc_epoch != last_epoch:
            plt.plot(max_acc_epoch, max_test_acc, marker='*', color=color, markersize=8)
            plt.annotate(f"Max: {max_test_acc:.1f}%",
                         xy=(max_acc_epoch, max_test_acc),
                         xytext=(-20, 10), textcoords='offset points',
                         color=color, fontsize=9)

    # --- 完善左图细节 ---
    plt.subplot(1, 2, 1)
    plt.title('Train and Test Loss Comparison', fontsize=14, fontweight='bold')
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel('Loss', fontsize=12)
    plt.legend(fontsize=9, loc='upper right')
    plt.grid(True, linestyle=':', alpha=0.7) # 加入虚线网格线更易读数据

    # --- 完善右图细节 ---
    plt.subplot(1, 2, 2)
    plt.title('Train and Test Accuracy Comparison', fontsize=14, fontweight='bold')
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel('Accuracy (%)', fontsize=12)
    plt.legend(fontsize=9, loc='lower right')
    plt.grid(True, linestyle=':', alpha=0.7)

    plt.tight_layout()

    # 保存高斯清晰度的图表
    save_path = os.path.join(FIGURES_DIR, 'all_models_comparison.png')
    # dpi=300 保证插入到 Word 报告或 PDF 中时放大不会模糊
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    print(f"🎉 所有模型的对比曲线图已成功生成并保存至: {save_path}")

    # 弹出窗口显示
    plt.show()

def plot_augmentation_comparison():
    # 两个实验的历史文件路径
    base_file = os.path.join(HISTORY_DIR, 'SimpleCNN.json')
    aug_file = os.path.join(AUGMENTED_HISTORY_DIR, 'SimpleCNN_augmented.json')

    # 检查文件是否存在
    if not os.path.exists(base_file) or not os.path.exists(aug_file):
        print(f"⚠️ 找不到 JSON 文件，请检查 {HISTORY_DIR} 目录下是否包含这两个文件！")
        return

    # 读取数据
    with open(base_file, 'r', encoding='utf-8') as f:
        history_base = json.load(f)
    with open(aug_file, 'r', encoding='utf-8') as f:
        history_aug = json.load(f)

    epochs = range(1, len(history_base['train_loss']) + 1)
    last_epoch = epochs[-1]

    # --- 颜色与线型设定 ---
    # 蓝色代表 Baseline(原版)，橙色代表 Augmented(数据增强版)
    color_base = '#1f77b4'  # 标准蓝
    color_aug = '#ff7f0e'   # 标准橙

    plt.figure(figsize=(14, 6))

    # ==========================================
    # 1. 绘制损失曲线 (左侧)
    # ==========================================
    plt.subplot(1, 2, 1)

    # Baseline 曲线
    plt.plot(epochs, history_base['train_loss'], linestyle='-', color=color_base, label='Baseline (Train)')
    plt.plot(epochs, history_base['test_loss'], linestyle='--', color=color_base, label='Baseline (Test)')

    # Augmented 曲线
    plt.plot(epochs, history_aug['train_loss'], linestyle='-', color=color_aug, label='Augmented (Train)')
    plt.plot(epochs, history_aug['test_loss'], linestyle='--', color=color_aug, label='Augmented (Test)')

    # 标注最后一次 Epoch 的测试集 Loss
    base_last_test_loss = history_base['test_loss'][-1]
    aug_last_test_loss = history_aug['test_loss'][-1]

    plt.annotate(f"{base_last_test_loss:.3f}", xy=(last_epoch, base_last_test_loss),
                 xytext=(5, 0), textcoords='offset points', color=color_base, fontsize=9, va='center')
    plt.annotate(f"{aug_last_test_loss:.3f}", xy=(last_epoch, aug_last_test_loss),
                 xytext=(5, 0), textcoords='offset points', color=color_aug, fontsize=9, va='center')

    plt.title('Loss Comparison: Baseline vs Data Augmentation', fontsize=13, fontweight='bold')
    plt.xlabel('Epoch', fontsize=11)
    plt.ylabel('Loss', fontsize=11)
    plt.legend(fontsize=9)
    plt.grid(True, linestyle=':', alpha=0.7)

    # ==========================================
    # 2. 绘制准确率曲线 (右侧)
    # ==========================================
    plt.subplot(1, 2, 2)

    # Baseline 曲线
    plt.plot(epochs, history_base['train_acc'], linestyle='-', color=color_base, label='Baseline (Train)')
    plt.plot(epochs, history_base['test_acc'], linestyle='--', color=color_base, label='Baseline (Test)')

    # Augmented 曲线
    plt.plot(epochs, history_aug['train_acc'], linestyle='-', color=color_aug, label='Augmented (Train)')
    plt.plot(epochs, history_aug['test_acc'], linestyle='--', color=color_aug, label='Augmented (Test)')

    # 标注最后一次 Epoch 的测试集 Acc
    base_last_test_acc = history_base['test_acc'][-1]
    aug_last_test_acc = history_aug['test_acc'][-1]

    plt.annotate(f"{base_last_test_acc:.1f}%", xy=(last_epoch, base_last_test_acc),
                 xytext=(5, 0), textcoords='offset points', color=color_base, fontsize=9, va='center')
    plt.annotate(f"{aug_last_test_acc:.1f}%", xy=(last_epoch, aug_last_test_acc),
                 xytext=(5, 0), textcoords='offset points', color=color_aug, fontsize=9, va='center')

    # (智能优化) 寻找并标注各自的最高准确率
    for hist, col, name in zip([history_base, history_aug], [color_base, color_aug], ['Base', 'Aug']):
        max_acc = max(hist['test_acc'])
        max_epoch = epochs[hist['test_acc'].index(max_acc)]
        if max_epoch != last_epoch:
            plt.plot(max_epoch, max_acc, marker='*', color=col, markersize=8)
            # 错开一点位置防止文字重叠
            offset = 10 if name == 'Aug' else -15
            plt.annotate(f"Max: {max_acc:.1f}%", xy=(max_epoch, max_acc),
                         xytext=(-20, offset), textcoords='offset points', color=col, fontsize=9)

    plt.title('Accuracy Comparison: Baseline vs Data Augmentation', fontsize=13, fontweight='bold')
    plt.xlabel('Epoch', fontsize=11)
    plt.ylabel('Accuracy (%)', fontsize=11)
    plt.legend(fontsize=9, loc='lower right')
    plt.grid(True, linestyle=':', alpha=0.7)

    plt.tight_layout()

    # 保存高清对比图
    save_path = os.path.join(FIGURES_DIR, 'augmentation_comparison.png')
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    print(f"🎉 数据增强对比图已生成并保存至: {save_path}")

    plt.show()

# %% [markdown]
# ### 5. 主函数

# %% [markdown]
# 以下函数为模型训练与评估主函数，确保在运行以上所有代码块进行函数定义后再运行。用时非常长，由于我已经完成了训练取得了数据存储在./history目录下，强烈建议直接跳过这一步。

# %%
if __name__ == "__main__":
    # 你可以切换选择不同的模型进行测试
    models_to_train = [
        LeNet5(),
        SimpleCNN(),
        MiniAlexNet(),
        ResNetModel(),    # 如果觉得太慢可以注释掉
        MobileNetModel()
    ]

    for model in models_to_train:
        print(f"Starting training with {model.model_name}...")
        train_and_eval(model)
        print("\n")

    model = SimpleCNN()
    print(f"Starting augmentation training with {model.model_name}...")
    train_and_eval_augmentation(model)
    print("\n")

# %% [markdown]
# 以下函数为运行绘图及可视化函数，需要运行第4章中的函数进行定义后才可以运行。

# %%
if __name__ == '__main__':
    plot_all_models()
    plot_augmentation_comparison()
# Out:
# 🎉 所有模型的对比曲线图已成功生成并保存至: ./Figures\all_models_comparison.png
# 🎉 数据增强对比图已生成并保存至: ./Figures\augmentation_comparison.png

# %% [markdown]
# ### 6. 分析与评估

# %% [markdown]
# 结果如下图所示：
# ![all_models_comparison.png](Figures/all_models_comparison.png)
# *表示测试集准确率的最高点，如果最高点不是最后一个点，我们才额外标注它，防止重叠
#
# 读图不难发现，所有数据集均出现了当Epoch较小时测试集损失比训练集更低，准确度更高，且随着Epoch增加训练集与测试集损失减小准确率升高，测试集损失逐渐超过训练集，训练集准确率逐渐超过测试集。随后继续训练，当Epoch较大时随着Epoch增加，训练集损失进一步下降但速度放缓，而测试集损失反而波动上升，虽然训练集与测试集准确率均趋于不变。说明模型训练出现了过拟合的现象，训练集效果变好，而测试集效果先变好到一定Epoch后反而变差了。过拟合的问题可以通过数据增强缓解，如下图所示：
# ![augmentation_comparison.png](Figures/augmentation_comparison.png)

# %% [markdown]
# 如图所示，虽然不加增强时测试集损失下降更快，但后续反而上升即出现了过拟合的问题，而加了增强后虽然开始下降没有那么快但持续下降，更低且更平稳，准确率也会一直升高，最终甚至可能超过不加增强时的准确率。这是因为开启数据增强后会导致训练难度上升，收敛速度变慢，但缓解了过拟合的问题。另外加了增强后测试集的损失居然一直比训练集更低，而准确率也一直比训练集更高，非常反直觉，可能是因为训练数据量比测试集更大、难度更高导致的，也有可能是CNN模型中nn.Dropout(0.5)导致训练模式是仅开启一半的神经元导致的。
